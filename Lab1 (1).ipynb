# %% [markdown]
# Before you turn this problem in, make sure everything runs as expected. First, **restart the kernel** (in the menubar, select Kernel$\rightarrow$Restart) and then **run all cells** (in the menubar, select Cell$\rightarrow$Run All).
#
# Make sure you fill in any place that says `YOUR CODE HERE` or "YOUR ANSWER HERE", as well as your name.

# %%
NAME = "Desmond Opoku Anane"

# %% [markdown]
# ### Please read all instructions carefully for each cell. Variable names must be defined as strictly as the question dictates.
# ### Enter your solution in the space marked "YOUR CODE HERE"
# Failure to do this will result in loss of marks for that question and maybe even subsequent questions.

# %% [markdown]
# # Lab 1 — DNA to RNA Transcription
#
# **Instructions:**
#
# - Use the given DNA sequence:
#   `AAAGGTCCTAGTTGG`

# %%
from Bio.Seq import Seq

# %%
# Task 1: Create a Seq object for the DNA
import Bio


def dna_seq():
    """
    Return a Bio.Seq.Seq object containing the DNA sequence.
    """
    
    from Bio.Seq import Seq
    seq = Seq("AAAGGTCCTAGTTGG")
    return seq.transcribe()
# The variable 'seq' should contain the DNA sequence.
seq = dna_seq()

# %%
### begin test
assert isinstance(seq, Seq), "seq must be a Bio.Seq.Seq object"
### end test
print("Test passed!")

# %%
# Task 2: Transcribe DNA to RNA
def transcribe_seq(dna_seq):
    """
    Transcribe a sequence to RNA.
    """
    rna_seq = dna_seq.transcribe()
    return dna_seq.transcribe()

# Transcribe sequence
answer = transcribe_seq(seq)

# %%
### begin test
expected_rna = Seq("AAAGGUCCUAGUUGG")
assert answer == expected_rna, f"Expected {expected_rna} but got {answer}"
### end test
print("Test passed!")
